# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
drinks = pd.read_csv('../data/drinks.csv')
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks.iloc[:, 2:5]
# Out:
#      spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0                  0              0                           0.0
# 1                132             54                           4.9
# 2                  0             14                           0.7
# 3                138            312                          12.4
# 4                 57             45                           5.9
# 5                128             45                           4.9
# 6                 25            221                           8.3
# 7                179             11                           3.8
# 8                 72            212                          10.4
# 9                 75            191                           9.7
# 10                46              5                           1.3
# 11               176             51                           6.3
# 12                63              7                           2.0
# ...

# %%
drinks['country'] = drinks['country'].replace('USA', '미국')

# %%
drinks['country']
# Out:
# 0               Afghanistan
# 1                   Albania
# 2                   Algeria
# 3                   Andorra
# 4                    Angola
# 5         Antigua & Barbuda
# 6                 Argentina
# 7                   Armenia
# 8                 Australia
# 9                   Austria
# 10               Azerbaijan
# 11                  Bahamas
# 12                  Bahrain
# 13               Bangladesh
# 14                 Barbados
# 15                  Belarus
# 16                  Belgium
# 17                   Belize
# 18                    Benin
# 19                   Bhutan
# 20                  Bolivia
# 21       Bosnia-Herzegovina
# 22                 Botswana
# 23                   Brazil
# 24                   Brunei
# 25                 Bulgaria
# 26             Burkina Faso
# 27                  Burundi
# 28            Cote d'Ivoire
# 29               Cabo Verde
#                ...
# 163                Suriname
# 164               Swaziland
# ...

# %% [markdown]
# # 1. 데이터에 대한 전체적인 살펴보기

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       170 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
cols = ['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol']

# %%
corr = drinks[cols].corr(method='pearson') #상관지수구하기, 피어슨상관!

# %%
corr #-1~1
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
type(corr)
# Out:
# pandas.core.frame.DataFrame

# %%
# beer_servings: 나라별 맥주소비량
# spirit_servings: 나라별 spirit소비량
# wine_servings: 나라별 와인소비량
# total_servings: 나라별 알콜소비량

# %%
# 맥주의 소비량 총 알콜소비량 상관이 높다.
# 와인을 많이 마시는 사람들이 반드시 맥주를 많이 마시는 것은 아니다. 
#  그렇지만, 완전 상관이 없는 것은 아니다.
# 스프라이트는 와인보다는 맥주와 좀더 상관이 있다.

# %%
# 항목간의 상관 관계를 알 수 있는 방법 3가지
# 1. corr함수를 이용(피어슨)
# 2. heap그래프
# 3. pairplot그래프

# %%
import seaborn as sns

# %%
cols_view = ['beer', 'spirit', 'wine', 'alcohol']

# %%
sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True, 
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=cols_view,
            xticklabels=cols_view)
plt.show()

# %%
# 시각화 라이브러리를 이용한 피처간의 scatter plot을 출력합니다.
sns.set(style='whitegrid', context='notebook')
sns.pairplot(drinks[['beer_servings', 'spirit_servings', 
                     'wine_servings', 'total_litres_of_pure_alcohol']], height=2.5)
plt.show()

# %% [markdown]
# # 2. 전처리

# %%
# info()함수를 이용해서 결측데이터를 확인함.
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       170 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.isnull()
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 0      False          False            False          False
# 1      False          False            False          False
# 2      False          False            False          False
# 3      False          False            False          False
# 4      False          False            False          False
# 5      False          False            False          False
# 6      False          False            False          False
# 7      False          False            False          False
# 8      False          False            False          False
# 9      False          False            False          False
# 10     False          False            False          False
# 11     False          False            False          False
# 12     False          False            False          False
# 13     False          False            False          False
# 14     False          False            False          False
# ...

# %%
drinks.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
# NA(Not Available): 결측치(+이상치)를 모두 NA처리를 함.
# NA로 모두 변경한 것을 일괄처리할 수 있다.

# %%
drinks['continent'] = drinks['continent'].fillna('OT')
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %% [markdown]
# # 3. 기술(설명)적 통계 : 통계를 통해서 데이터들을 자세하게 설명해보자

# %%
drinks['continent'].value_counts() #value_counts() : 그룹별 count
# Out:
# AF    53
# EU    45
# AS    44
# OT    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
con_val_count = drinks['continent'].value_counts()
type(con_val_count)
# Out:
# pandas.core.series.Series

# %%
#Series는 index와 values의 결합

# %%
con_val_count.index
# Out:
# Index(['AF', 'EU', 'AS', 'OT', 'OC', 'SA'], dtype='object')

# %%
pie_label = con_val_count.index

# %%
con_val_count.values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
pie_values = con_val_count.values

# %%
explode = (0, 0, 0, 0.25, 0, 0)

plt.pie(pie_values, explode=explode, labels=pie_label, autopct='%.0f%%', shadow=True)
plt.title('null data to \'OT\'')
plt.show()

# %%
result = drinks.groupby('continent').spirit_servings.agg(['mean','min','max', 'sum'])
result
# Out:
#                  mean  min  max   sum
# continent
# AF          16.339623    0  152   866
# AS          60.840909    0  326  2677
# EU         132.555556    0  373  5965
# OC          58.437500    0  254   935
# OT         165.739130   68  438  3812
# SA         114.750000   25  302  1377

# %%
result2 = drinks.groupby('continent').spirit_servings.mean()
result2
# Out:
# continent
# AF     16.339623
# AS     60.840909
# EU    132.555556
# OC     58.437500
# OT    165.739130
# SA    114.750000
# Name: spirit_servings, dtype: float64

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
type(result2)
# Out:
# pandas.core.series.Series

# %%
result3 = drinks.groupby('continent')['spirit_servings'].mean()
result3
# Out:
# continent
# AF     16.339623
# AS     60.840909
# EU    132.555556
# OC     58.437500
# OT    165.739130
# SA    114.750000
# Name: spirit_servings, dtype: float64

# %%
type(result3)
# Out:
# pandas.core.series.Series

# %%
result4 = result3[result3 >= 100]
result4
# Out:
# continent
# EU    132.555556
# OT    165.739130
# SA    114.750000
# Name: spirit_servings, dtype: float64

# %%
result4.idxmax() #result4의 values중에서 제일 max값의 인덱스를 리턴
# Out:
# 'OT'

# %%
# 맥주 총(sum) 소비량이 제일 높은  대륙은?
# 와인 최대(max) 소비량이 제일 높은 대륙은?
# 맥주 평균(mean) 소비량이 제일 높은 대륙은?

# %%
result.head()
# Out:
#                  mean  min  max   sum
# continent
# AF          16.339623    0  152   866
# AS          60.840909    0  326  2677
# EU         132.555556    0  373  5965
# OC          58.437500    0  254   935
# OT         165.739130   68  438  3812

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result.index
# Out:
# Index(['AF', 'AS', 'EU', 'OC', 'OT', 'SA'], dtype='object', name='continent')

# %%
drinks['total_litres_of_pure_alcohol'].mean()
# Out:
# 4.717098445595855

# %%
drinks.total_litres_of_pure_alcohol.mean()
# Out:
# 4.717098445595855

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
n_groups = len(result.index)
means = result['mean'].tolist()
mins = result['min'].tolist()
maxs = result['max'].tolist()
sums = result['sum'].tolist()
 
index = np.arange(n_groups)
bar_width = 0.1
 
rects1 = plt.bar(index, means, bar_width,
                 color='r',
                 label='Mean')
 
rects2 = plt.bar(index + bar_width, mins, bar_width,
                 color='g',
                 label='Min')

rects3 = plt.bar(index + bar_width * 2, maxs, bar_width,
                 color='b',
                 label='Max')
 
rects3 = plt.bar(index + bar_width * 3, sums, bar_width,
                 color='y',
                 label='Sum')

plt.xticks(index, result.index.tolist())
plt.legend()
plt.show()

# %%
# "와인"으로 여기까지 그려서 올려주세요.!

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks['total_all'] = drinks['beer_servings'] + drinks['wine_servings'] + drinks['spirit_servings']
drinks['total_all'].head()
# Out:
# 0      0
# 1    275
# 2     39
# 3    695
# 4    319
# Name: total_all, dtype: int64

# %%
drinks['bear_rates'] = drinks['beer_servings']/drinks['total_all']
drinks['bear_rates']
# Out:
# 0           NaN
# 1      0.323636
# 2      0.641026
# 3      0.352518
# 4      0.680251
# 5      0.370909
# 6      0.439636
# 7      0.099526
# 8      0.478899
# 9      0.511927
# 10     0.291667
# 11     0.349570
# 12     0.375000
# 13          NaN
# 14     0.406250
# 15     0.254937
# 16     0.499154
# 17     0.683117
# 18     0.666667
# 19     1.000000
# 20     0.773148
# 21     0.295720
# 22     0.711934
# 23     0.603448
# 24     0.911765
# 25     0.400347
# 26     0.641026
# 27     1.000000
# 28     0.822222
# 29     0.666667
#          ...
# 163    0.408946
# 164    0.957447
# 165    0.381910
# 166    0.327434
# 167    0.089286
# 168    0.117647
# 169    0.276536
# 170    0.484018
# 171    0.166667
# 172    0.631579
# 173    0.580645
# 174    0.547222
# 175    0.689189
# 176    0.637500
# 177    0.155738
# 178    0.107143
# 179    0.833333
# 180    0.422131
# 181    0.102564
# 182    0.405556
# 183    0.837209
# 184    0.507128
# 185    0.310811
# 186    0.186567
# ...

# %%
drinks.dropna(axis=0)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# ...

# %%
wine_mean = drinks['wine_servings'].mean()
wine_mean
# Out:
# 49.45077720207254

# %%
beer_mean = drinks['beer_servings'].mean()
beer_mean
# Out:
# 106.16062176165804

# %%
beer_up_country = drinks[drinks['beer_servings'] > beer_mean]
beer_up_country.head(10)
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 4      Angola            217               57             45
# 6   Argentina            193               25            221
# 8   Australia            261               72            212
# 9     Austria            279               75            191
# 11    Bahamas            122              176             51
# 14   Barbados            143              173             36
# 15    Belarus            142              373             42
# 16    Belgium            295               84            212
# 17     Belize            263              114              8
#
#     total_litres_of_pure_alcohol continent  bear_rates  total_all
# 3                           12.4        EU    0.352518        695
# 4                            5.9        AF    0.680251        319
# 6                            8.3        SA    0.439636        439
# ...

# %%
beer_up_country['country']
# Out:
# 3                           Andorra
# 4                            Angola
# 6                         Argentina
# 8                         Australia
# 9                           Austria
# 11                          Bahamas
# 14                         Barbados
# 15                          Belarus
# 16                          Belgium
# 17                           Belize
# 20                          Bolivia
# 22                         Botswana
# 23                           Brazil
# 25                         Bulgaria
# 29                       Cabo Verde
# 31                         Cameroon
# 32                           Canada
# 35                            Chile
# 37                         Colombia
# 41                       Costa Rica
# 42                          Croatia
# 44                           Cyprus
# 45                   Czech Republic
# 48                          Denmark
# 51               Dominican Republic
# 52                          Ecuador
# ...

# %%
len(beer_up_country)
# Out:
# 76

# %%
beer_up_country['beer_servings'].mean()
# Out:
# 215.47368421052633

# %%
beer_up_country['country'][beer_up_country['country'] == 'South Korea']
# Out:
# 138    South Korea
# Name: country, dtype: object

# %%
beer_sort_result = beer_up_country.sort_values(['beer_servings'], axis=0, ascending=False)
beer_sort_result.head(15)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 135          Poland            343              215             56
# 98        Lithuania            343              244             56
# 188       Venezuela            333              100              3
# 81          Ireland            313              118            165
# 129           Palau            306               63             23
# 140         Romania            297              122            167
# 16          Belgium            295               84            212
# 130          Panama            285              104             18
# 160           Spain            284              157            112
# ...

# %%
beer_sort_result.reset_index(drop=False, inplace=True)

# %%
beer_sort_result
# Out:
#     index                       country  beer_servings  spirit_servings  \
# 0     117                       Namibia            376                3
# 1      45                Czech Republic            361              170
# 2      62                         Gabon            347               98
# 3      65                       Germany            346              117
# 4     135                        Poland            343              215
# 5      98                     Lithuania            343              244
# 6     188                     Venezuela            333              100
# 7      81                       Ireland            313              118
# 8     129                         Palau            306               63
# 9     140                       Romania            297              122
# 10     16                       Belgium            295               84
# 11    130                        Panama            285              104
# ...

# %%
beer_sort_result[beer_sort_result['country'] == 'South Korea'].index
# Out:
# Int64Index([65], dtype='int64')

# %%
drinks['country'][drinks['country'] == 'South Korea']
# Out:
# 138    South Korea
# Name: country, dtype: object

# %%
drinks[drinks['country'] == 'South Korea'].index
# Out:
# Int64Index([138], dtype='int64')

# %%
drinks['country'][138]
# Out:
# 'South Korea'

# %%
result_rank = drinks['beer_servings'].rank(method='max')
result_rank[result_rank == 193]
# Out:
# 117    193.0
# Name: beer_servings, dtype: float64

# %%
drinks.iloc[117]
# Out:
# country                          Namibia
# beer_servings                        376
# spirit_servings                        3
# wine_servings                          1
# total_litres_of_pure_alcohol         6.8
# continent                             AF
# bear_rates                      0.989474
# total_all                            380
# Name: 117, dtype: object

# %%
beer_asia = drinks[drinks['beer_servings']
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# OT                  3345             3812            564
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol  bear_rates  total_all
# continent
# AF                                159.4   33.729385       4986
# AS                                 95.5   15.677868       4706
# EU                                387.8   17.119326      21085
# OC                                 54.1    7.742063       2940
# OT                                137.9   10.034946       7721
# SA                                 75.7    6.186719       4227

# %%
type(result_continent)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: D888-6FE5
#
#  C:\Users\tjoeun709\Documents\data15 디렉터리
#
# 2021-05-04  오후 04:22    <DIR>          .
# 2021-05-04  오후 04:22    <DIR>          ..
# 2021-05-04  오전 10:06    <DIR>          .ipynb_checkpoints
# 2021-05-04  오후 04:22           554,697 국가별음주데이터분석.ipynb
#                1개 파일             554,697 바이트
#                3개 디렉터리  338,031,570,944 바이트 남음

# %%
# !pip install scipy
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 21.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
africa = drinks.loc[drinks['continent'] == 'AF']
europe = drinks.loc[drinks['continent'] == 'EU']

# %%
from scipy import stats

# %%
stats.ttest_ind(africa['beer_servings'], europe['beer_servings'])
stats.tt
# Out:
# Ttest_indResult(statistic=-7.267986335644365, pvalue=9.719556422442453e-11)

# %%
import scipy

# %%
scipy.__version__
# Out:
# '1.1.0'

# %%
# africa와 europe간의 평균의 차이가 의미가 있다. 대립가설이 채택!
# 대립가설: 아프리카, 유럽간 평균의 차이가 있다.
# 영가설: 아프리카, 유럽간 평균의 차이가 없다. (가능성 0.05미만인 경우)

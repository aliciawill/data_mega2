# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip3 install requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.19.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (4.2.5)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2018.8.24)

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%EC%8B%A0%ED%9D%A5%EC%9E%AC
# https://namu.wiki/w/%ED%9E%88%EB%A9%94%EC%A7%80%EB%A7%88%20%EA%B5%90%EB%A9%94%EC%9D%B4/%EC%9E%91%EC%A4%91%20%ED%96%89%EC%A0%81
# https://namu.wiki/w/%EC%86%8C%EC%9D%98%EB%AC%B8
# https://namu.wiki/w/%EC%9B%90%ED%8E%80%EB%A7%A8/%EB%93%B1%EC%9E%A5%EC%9D%B8%EB%AC%BC
# https://namu.wiki/w/%ED%95%9C%EA%B5%AD%EA%B5%90%EC%9B%90%EB%8C%80%ED%95%99%EA%B5%90

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 밍꼬발랄
#
#
# 밍꼬발랄
#
#
# 장르병맛, 코미디, 일상, 공감활동명밍꼬 (Mingggo)본명박민정생년월일1994년 2월 6일(빠른 생일)거주지제주특별자치도신체168cm학력백제예술대학교 (실용음악과 / 학사)가족부모님, 언니 박지선[1], 남동생 박찬일[2]구독자 애칭꼬밍[3]유튜브 가입일2018년 6월 18일[4]구독자 수103만 명[업데이트]조회수1,171,495,576회[업데이트]유튜브 채널SNS / 관람 등급 12세 이상 관람가[7]시청 등급 15세 이상 시청가[8]1. 개요2. 역사3. 콘텐츠3.1. 일반 유형3.2. 공소시효3.3. 노래하는 밍디오3.4. 유형드라마3.5. 밍꼬박스3.6. 밍꼬로그3.7. 모아보기3.8. 밍꼬도전3.9. 밍웅밍웅4. 등장인물5. 비판5.1. 극성팬 방관6. 도서7. 음원7.1. 밍꼬송8. 여담똥꼬발랄 밍꼬의 1인 다역 병맛 코믹 유튜브채널 설명대한민국의 유튜브 크리에이터.밍꼬발랄은 이름 가운데 자리인 '민'을 애교스럽게 변경한 '밍'과 자신이 좋아하던 성격인 똥꼬발랄을 합친 것이다.직업성우를 꿈꿔와서 4년 반 동안 성우시 험을 준비했지만 번번히 불합격하는 바람에 좌절하던 중 막내 동생이 보여준 유튜브를 보고 '크리에이터'라는 직업을 처음 알았다고 하며, 준비하던 성우와 잘 맞을 것 같아서 크리에이터의 길을 걷게 되었다고 한다. 출처초기엔 유형영상을 올렸고 일상에서 있을법한 이야기의 병맛 영상이었다. 편집이 현재보다 심플하고 짧고 굵은 느낌이였다. 등장인물은 밍꼬가 그 때에도 있었으나 이름도 정확히 정해져 있지 않았고 헤어스타일도 고정적이지 않는 등[9] 지금과는 다른 캐릭터로 고등학생이나 대학생으로 나오는 경우가 많았다.그러다 공소시효(공: 공감 소: 소통 시: 시청 효: 효과) 라는 컨텐츠를 시작해 시청자들의 사연을 받아 1인 다역으로 영상을 제작했다. 초기엔 단순히 사연을 연기하였으나 점점 여러 효과가 추가되면서 되감기 공소시효, 코믹 공소시효 등의 여러 부류로 올라가기 시작했다.그러다 유형드라마가 시작되었다. 자세한 건 밍꼬발랄 유형드라마 문서 참조. 이전에도 교복을 입은 학생들이 나왔으나 거의 일회성에 캐릭터성도 일정치 않았다.그러다 여러 부류의 영상들이 담긴 밍꼬박스를 시작하였다.주로 1인 다역으로 유형별 공감 컨텐츠를 제작한다. 모든 컨텐츠를 병맛 컨셉을 잡고 진행하는 것이 특징. 가끔씩 일상 Vlog도 제작을 한다. 컨텐츠 촬영과 편집은 PD 6명(밍디)이서 도와 준다고 한다.업로드 시간표요일시간월요일휴방화요일오후 6시수요일오후 6시목요일휴방금요일오후 6시토요일오전 9시일요일오전 9시2021년부터 위와 같이 업로드 일정이 바뀌었다. 공소시효 사건제보가 19만개에 육박하고, 요일별로 특정 콘텐츠 업로드 등을 지속하다보니 무리가 와서 주 6회 업로드에서 주 5회 업로드로 휴방 요일에 목요일이 추가되었다. 앞으로 요일에 상관없이 자유롭게 컨텐츠를 업로드 할 것이라고 한다.[10] 하지만 여전히 이전처럼 화요일은 공소시효, 수요일은 일반유형, 금요일은 유형 드라마, 토요일은 밍꼬박스, 일요일은 모아보기 영상이 올라오는 것으로 사실상 고정되어있다.많이 등장하는 주역 인물 6명은 박밍꼬, 김발랄, 오밍밍, 이웅, 황꼬꼬, 이두리다. 가끔씩 또는 일회성으로 나오는 등장인물은 박밍꼬와 친구들이 다니는 학교인 유튭중 다른반 친구들, 구글중 일진무리 등이 있다. 또한 김발랄의 오빠인 김발랑도 나온다.일상생활에서 벌어질 법한 일을 보여주는 콘텐츠. 가장 초창기 때부터 업데이트 되어 가장 오래된 컨텐츠이다.처음 올린 영상은 주변에 꼭 있는 친구 유형이며, 가장 조회수가 많이 나온 영상은 바닥에 음식 떨어졌을 때 유형이다.[11]  자세한 내용은 밍꼬발랄/공소시효 문서를의 번째 문단을의  부분을 참고하십시오.공소시효에서 다루지 못했던 미공개 사건파일들을 밝히고, 음악으로 속을 후련하게 해주는 컨텐츠. 하지만 음악저작권 때문에 더 이상 올라오지 않고 있다.  자세한 내용은 밍꼬발랄 유형드라마 문서를의 번째 문단을의  부분을 참고하십시오.여러 장르의 이야기를 담았다. '동화 주인공 빙의'나 '내가 영웅이라면' 등. 시작할때 밍꼬송이 앞부분 일부만 나온다.내레이션편이나 영웅편 그리고 선택편 등등 여러가지 버전이 있다.밍꼬발랄의 브이로그 영상이다.밍꼬가 혼자서 촬영사는 브이로그는 청순하다. 평소에 올리던 영상과는 다르게 브이로그는 다른 유튜버들이랑 비슷하게 청순하게 제작한것같다.브이로그영상의 종류는 가족들과 호캉스 브이로그 등등,그리고 웅이와 백일 데이트 준비 과정 영상등이 있고 언니의 결혼식 영상을 시청하는 브이로그 등을 찍었다.유형, 유형드라마, 공소시효, 밍꼬박스 등을 모아 보여주는 영상이다. 평균 영상이 길 때는 3~5개, 짧을 때는 2~3개씩 나오기도 한다.밍꼬발랄의 도전 영상이다. 밍꼬로그와 같이 가끔씩 올라 온다.[밍꼬로그와]등장인물 중 박밍꼬와 이웅이 진행하는 콘텐츠. 밍꼬박스의 일부로 취급되는 듯.듣거나 말거나 - 꼬밍이들의 고민이나 걱정을 랜덤 인물 중 한 명이 한 줄로 해결해주는 코너로 아주 황당한 조언이 대부분이기 때문에 들을지 말지는 본인 선택(...)기억해주세요 - 짧은 상황극을 통해 속담을 함께 배우는 시간미니미니게임 - 스튜디오에서 직접 하는 게임이나 모바일 게임, 간단한 컴퓨터 게임 등을 하는 시간내 맘대로 놀이터 - 자유롭게 상상의 나래를 펼치는 시간으로 대사없는 상황을 보여주면 꼬밍이들이 그 상황에 맞는 대사를 만들어 댓글에 적으면 다음시간에 그대로 재연해준다.  자세한 내용은 밍꼬발랄/등장인물 문서를의 번째 문단을의  부분을 참고하십시오.초등학생 극성팬들이 존재하는데, 이러한 극성팬들에 대한 별다른 언급, 혹은 조치를 취하고 있지 않아 비판을 받는다.[13][14]또한 댓글에서 전혀 관련 없는 댓글이나 좋아요를 구걸하는 댓글이 적지 않은데도 아무 반응이 없다는 것도 문제이다. 계속 방관을 하면 구걸하는 초등학생들은 어차피 밍꼬발랄이 아무 반응을 하지 않을 것이라고 생각해 계속 구걸을 할 수 있기 때문.겜툰에서 본인의 캐릭터가 나오는 만화책을 출간했다. 밍꼬발랄 본편과 연동되지 않고 설정이 다르다.밍꼬발랄 코믹스밍꼬발랄 코믹스 1밍꼬발랄 코믹스 2밍꼬발랄 코믹스 3밍꼬발랄 코믹스 4발매일: 2019년 12월 22일발매일: 2020년 2월 20일발매일: 2020년 4월 20일발매일: 2020년 6월 20일평범한 소녀 박밍꼬가 어느날 의문의 할머니에게서 '밍꼬발랄'이라는 책을 사 펼쳤더니 자신과 똑같은 얼굴로 가득한 책속으로 들어가 있었다. 책이 있는 곳에 표식이 보이고 책을 찾아야 돌아갈 수 있다는 정보를 듣고 밍꼬발랄 코믹스를 찾기 위해 열을 다하는 와중에 책 속 밍꼬네 반에 전학 온 아이돌 연습생인 이웅과 엮이게 되면서 생기는 이야기이다. 밍꼬발랄 공소시효10만 구독자를 기념해 밍꼬송을 만들기로 처음 계획했고, 밍꼬발랄은 시청자에게 투표를 하는 방식으로 3개의 음원, 그리고 창작한 것을 제출하는 방식으로 가사 아이디어를 쓰는 이벤트를 열었다. 결국 당시 '1번 곡'으로 불렸던 음원이 가장 많은 지지를 얻어 현재의 밍꼬송이 되었다.다음은 밍꼬송의 가사이다.여러분 안녕 밍꼬에요 오늘은 무슨 일들이 일어날까  꼬밍이들 모두 모여라 오늘도 우리 다 함께 시끌벅적 놀아봐요  (간주)  한 번 들어오면 (나갈 수가 없어~!) 어느새 너도 꼬밍이가 될 걸  구독과 좋아요 (알림설정까지!) 밍꼬와 함께 놀아보자  여러분 안녕 밍꼬에요 오늘은 무슨 일들이 일어날까  꼬밍이들 모두 모여라 오늘도 우리 다 함께 시끌벅적 놀아봐요  다양한 얘기들 (입맛대로 골라~) 어쩌면 내 얘기가 나올 지도  다양한 유형들 (공소시효까지)  패러디, 도전들~도 모두  외롭고 슬픈 기분일 땐 밍꼬를 찾아 와!  여러분 안녕 밍~꼬에요![15] 오늘은 무슨 일들이 일어날까  꼬밍이들 모두 모여라 오늘도 우리 다 함께 시끌벅적 놀아봐요  (구x4 구독 구독 구독 좋아요 x7 알림 클릭 클릭 하~!! 구독 구독 구독 좋아요 x7 알림 클릭 클릭 하x7[16]~!!)왼손잡이다. 영상에서도 펜을 쓰는 장면이 나올 때 등장인물들이 왼손으로 글을 쓴다. 남동생도 왼손잡이라고.자신의 친언니 결혼식에서 동생과 축가를 불러 주었다.[17]2019년  ...

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# %%
# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#              title                                           category  \
# 0             신흥재   한국 남성 코미디언/ㅅ유튜버/ㅅ거창 신씨1984년 출생1등미디어등/등장인물김해시 출...
# 1  히메지마 교메이/작중 행적                                        귀멸의 칼날/작중 행적
# 2             소의문                               조선 시대의 없어진 건축물서울 한양도성
# 3        원펀맨/등장인물                                            원펀맨/등장인물
# 4         한국교원대학교                                             한국교원대학교
#
#                                         content_text
# 0    신흥재愼興宰 | Shinheungjae출생1984년 10월 30일(36세) 경상...
# 1     상위 문서: 히메지마 교메이1. 개요2. 작중 행적2.1. 과거2.2. 귀살대...
# 2  한양도성의 성문 및 종각창의문彰義門북소문숙정문肅靖門북대문혜화문惠化門동소문돈의문敦義門...
# 3  등장인물 | 히어로 (S급·A급·B급·C급) | 괴인 (재해 레벨) | 설정 (도시...
# 4   한국교원대학교 관련 틀 [ 펼치기 · 접기 ] 대한민국의 국립고등교육기관 [ 펼치...

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
#   신흥재  출생년 월 일세 경상남도 김해시거주지 서울특별시 마포구 연남동국적 대한민국본관거창 신씨신체  형데뷔년  웃찾사 타임머신데뷔일로부터 일째주년학력경운초등학교 졸업 임호중학교 졸업 김해고등학교 졸업 세종대학교 전자정보통신공학부휴학경력 공채 기 개그맨     김해시 홍보대사 위촉수상제 회 세상을 바꾸는 인플루언서 어워드 본상    소개 출연 작품 방송 웹드라마 유튜브 라디오 유행어 등 미디어에서의 컨셉 여담안녕하세요 저는 신이 난다 흥이 난다 재미 난다 신흥재라고 합니다 반갑습니다 웃찾사로 데뷔한 대한민국의 코미디언정식 데뷔 전 웃찾사에서 선배들 코너에서 방송에 나오고 소극장에서도 개그 공연을 한 후 년 월 일 타임머신이라는 코너로 공채로 데뷔를 하였다웃찾사가 폐지된 후 유튜브 채널 등 미디어  를 김성기 김재희와 운영 중이다년 월 일부터 개인 채널을 운영하고 있다 매주 토요일 시에 영상을 올리고 있었지만 무슨 이유인지 현재 올라오지 않고 있다영상 주제는 먹방이다채널프로그램명비고 웃찾사타임머신  카리스마 유봉쌤  풍문으로 들었소 문과이과 누가 진상인가개그투나잇뻔데기 펀  왜그래  대한민국  갤럭시 프로젝트  뉴스가 있는 저녁채널프로그램명비고내 상사는 백만 유튜버신흥재 역채널프로그램명비고 퇴사하기 있긔 없긔 진행세상에 이런 이진행노동에 도른 자들 진행어반로드  서울미래유산 편 고정 출연 서울디자인재단등미디어 디자인을 만나다 고정 출연채널프로그램명 비고트렌드피디쇼 크리에이터 세터 게스트 회썰빵 게스트 회 부바로 그거지이과젝틀리 그 각이 몇 도인지 구하시오칼카나마알아철니 수헬리베붕탄질산수금지화목토천해 분자가 분모보다 작으면 진분수 분자가 분모보다 크면 가분수         일십백천만 억조경해자 양구간정재극 분이면 충분해 여기서 떡볶이집까지의 거리  너가 를 초에 뛴다고 치면 걸리는 시간은  거기서 떡볶이튀김순대를 계산하고 포장하는데 걸리는 시간을 라고 따지고 다시 돌아오는데 걸리는 시간은 가 걸리겠지 왜 가 늘어난지 알아 떡볶이에 무게가 속도에 영향을 끼쳤기 때문이지이과 등신이 난다 흥이 난다 재미 난다등 미디어에서 문과 등과 같이 주인공으로 일등고등학교의 이과 등의 역할이다 정확한 계산과 수치를 좋아하며 상대의 말을 수학 과학적으로 반박한다영상에서 보면 이과 등이 많이 속고 당하는 편이다 불쌍할 정도년 전 이과 등이 불량 학생이였을 때 문과 등의 끈질긴 권유로 공부에 관심을 가지고 이과 등이 되었다 신흥재내가 보여줄게 전국 제패현재 전국 대표주자다 년 전 기메중 시절 너무나 약했기에 괴롭힘을 당했지만 당당함이 넘쳤다 그걸 알아챈 그의 스승 강경호에게 자신을 지킬 수 있는 격투기 기술을 배웠다 그러는 도중 이과적인 분노가 끓게 만드는 바람에 스승은 만 알려주었다고때 순식간에 김해 대표주자가 되었고 일등고로 전학을 와서 이과 등이 되었지만 문과 등의 일기장을 본 후 배신감에 완전히 틀어졌다 이젠 더 이상 예전의 이과 등이 아닌 신흥재로 돌아왔고 완벽한 그의 계획으로 잘 나신 그 분을 이긴 김성기를 안경 트라우마를 이용하여 대결에서 이겨 전국 대표주자가 되었다 신흥잼신이 난다 흥이 난다 잼난다이과 등 신흥재의 동생이다 잠옷이 항상 라이언 잠옷인 것으로 보아 형처럼 라이언을 좋아하는 듯 하다 형처럼 사투리를 쓴다신흥미신이 난다 흥이 난다 미안해뒤에서 등 소개팅녀와 문과 등의 꿈 속에서 문과 등의 여친으로 나왔다 쓸데없이 이쁘다신흥자행복은 성적순이 아니잖아요년 기준 만 세로 전교 꼴등뒤에서 등 아님의 엄마다신흥핑  등 캠핑캠핑 등이다 캠핑에 필요한 물건들을 잘 알고 있다뒤에서 등 엄마나도 사랑해요이과 출신으로 뒤에서 등 엄마다 이과 등이 엄마처럼 행동을 해서 그것 때문에 뒤에서 등이 이과 등을 괴롭힌다 뒤에서 등이 엄마 앞에서 욕을 쓰면 난리가 난다부자 아빠아빠도 아빠가 처음이라 많이 서툴다년생이고 자식은 일등여고 문과 등 주현정 이영석 그리고 막내아들이 있다 집 크기는  평이다 차는 벤츠  클래스 오너를 탄다고 한다건달쌤눈깔이 뿌리채 뽑아가 호두과자로 만들어뿐다건달 컨셉의 선생님이다 항상 야구방망이를 들고 다닌다 지각 한 번 했다고 패거리들을 모아 학생들을 족치려고 한다루트확률을 높이면 돼이과 출신의 타짜로 확률 싸움의 대가다 감정 없는 계산기라고 한다 약 년 전 루트의 이과 가문의 통일 이과 시대로 문과 이과 예체능이 통합을 하였으나 문과 출신 타짜 초아의 할아버지로 인해 년 전에 깨지고 말았다 이과 가문의 영광을 위해 타짜끼리의 싸움에서 이기려고 초아의 휘파람 소리에 넘어가지 않기 위해 한 쪽 귀를 포기했다자신을 소개할 때 하는 멘트가 두 가지 있다안녕하세요 저는 유튜브 등 미디어라는 채널에서 이과 등 역할을 맡고 있는 개그맨 신흥재라고 합니다 반갑습니다안녕하세요 저는 신이 난다 흥이 난다 재미 난다 신흥재라고 합니다 반갑습니다동안이다 밤 시에 교복 입고 방에 가기 몰카에서는 진짜 학생이라고 오해받았다초등학생 때 전교 부회장이 되었었다 회장 선거 운동 때 팻말에 신이 난다 흥이 난다 재미 난다 라고 썼다고 한다카카오프렌즈 라이언을 좋아한다  등 미디어에서도 가끔 라이언 잠옷을 입고 나오거나 집에 엄청 많은 라이언 제품들이 있고 등 미디어 사무실에도 라이언 액자가 걸려있는 등 굉장한 라이언 덕후다 또한 먹방 채널에서 보라색 먹방 영상 때 보라색 라이언 잠옷을 입고 찍기도 하였다퇴사하기 있긔 없긔  회에서 자신이 홍안빨간 얼굴이라고 밝힌 적이 있다 그 때 게스트가 화장품 직원인데 술 많이 먹지 않냐고 물었더니 뜨끔하는 모습을 보였다퇴사하기 있긔 없긔  회에서 대학교 다닐 때 학점이 이였다고 말한 적이 있었다 그리고 인스타그램에서 학년 때 학점이 이였다고 말하기도 하였다 그 게시물의 해시태그에 학교보다 당구장을 더 많이 갔다는 내용이 있다초등학교 학년 때 모든 과목의 성적이 수 였으나 수학만 우 였다고 한다초등학교 때 진로희망이 의사였으나 부모님께서는 판사를 원하셨다고 한다실제로 매운 음식을 잘 먹는다 신길동 매운 짬뽕을 여러 번 먹어봤다고 한다짝눈이다 그래서 그런지 양옆에서 봤을 때 이미지가 다른 느낌이 있다지금은 그만뒀지만 바이올린을 년 연주했다고 한다김해 본가에 요미라는 개가 있다 좋아하는 견종이 코가 낮은 어글리 강아지라고 한다지금은 오른손잡이지만 과거엔 왼손잡이였다 페이스북에서 왼손잡이 출신 위인이 아인슈타인 버락 오바마 그리고 자신이라고 적은 적이 있다회 중에서 대방어를 좋아한다고 한다현재 사용하고 있는 폰의 기종은 아이폰   이다웃찾사 타임머신을 했을 당시 차비가 없어서 대학로와 홍대를 걸어서 오갔다고 한다원래 시력이 낮지는 않다 주로 안경은 알이 없는데 한 번씩 알 있는 안경을 쓰고 나올 때가 있다 하지만 알 있는 안경도 도수가 있는 안경이 아니라고 만주년 기념 라이브에서 말한 적이 있다 탕수육 부먹 찍먹  상관 없음짜장면 짬뽕  짜장면물냉면 비빔냉면  비빔냉면떡볶이 순대  순대된장찌개 김치찌개  김치찌개굽네치킨을 좋아한다고 했다 과거 굽네에서 제일 좋아하는 치킨이 볼케이노라고 말을 하였다라면 중 너구리를 제일 좋아한다고 했다이 영상에서 재희님이 너구리 라면을 사라고 했을때 성기님이 솔깃한 이유가 이것이다목욕탕에서 팬을 만난 적이 있다고 한다   실제 인터뷰 내용 나는 말하기 조금 민망한데 목욕탕에서 만난 한 남자아이가 제일 기억에 남아 목욕탕에서 우연히 마주쳤는데 완전 팬이라면서 졸졸 따라다니더라고 따뜻한 물속에 몸을 담그고 있을 때도 큰 목소리로 이과 등 개그맨 재밌어라고 하기에 기분 좋으면서도 부끄러웠어롯데 팬인듯 하다

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#             title                                           category  \
# 0            신흥재   한국 남성 코미디언ㅅ유튜버ㅅ거창 신씨년 출생등미디어등등장인물김해시 출신 인물먹방 크...
# 1  히메지마 교메이작중 행적                                         귀멸의 칼날작중 행적
# 2            소의문                               조선 시대의 없어진 건축물서울 한양도성
# 3        원펀맨등장인물                                             원펀맨등장인물
# 4        한국교원대학교                                             한국교원대학교
#
#                                         content_text
# 0    신흥재  출생년 월 일세 경상남도 김해시거주지 서울특별시 마포구 연남동국적 대한...
# 1    상위 문서 히메지마 교메이 개요 작중 행적 과거 귀살대 주합 재판 편 무한열차 ...
# 2  한양도성의 성문 및 종각창의문북소문숙정문북대문혜화문동소문돈의문서대문보신각 중앙 종각...
# 3  등장인물  히어로 급급급급  괴인 재해 레벨  설정 도시애니메이션  기   기  변...
# 4   한국교원대학교 관련 틀  펼치기  접기  대한민국의 국립고등교육기관  펼치기  접...

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 신흥재 히메지마 교메이작중 행적 소의문 원펀맨등장인물 한국교원대학교 랜덤로얄문제점 데이비드 베컴 파일   좀비 코로나바이러스감염증백신대한민국 파일소설반여단    에이지 오브 엠파이어  결정판캠페인 공략오트빌 마리아 루스 호 사건  마인크래프트아이템더미 데이터 및 삭제 요리용디 샨 민주주의민족동맹 파일 틀대한민국의 영화 배급사 한강 의대생 실종 사건경과 마인크래프트아이템건축 블록 여성징병제 청원 후이 폰테 정규수 동방환상향     커트 코베인 종로구선거구   영화사업본부 냥코 대전쟁발굴 스테이지 후카미야 하야토 헌혈 시라사기 치사토 클리블랜드 인디언스년월 선풍기 사망설 야인시대합성물 조립 컴퓨터견적 테루하시 코코미  동방 로스트워드 코튼  스타벅스메뉴 철구 사랑에 미치다 콜럼바인 고교 총기난사 사건 고종 군밤의 왕등장인물 림월드 짤방목록 세스 후랭코프 풍운 타케시성 경기모바일과학고등학교 마인크래프트서버강제 퇴장 메시지 마이애미 히트   마이너 갤러리 마인애플 연두부인터넷 방송인 플레이게임 리스트 공화당미국 스코틀랜드 독립운동   아이템 유용민 스타 플래티나 냥코 대전쟁스페셜 스테이지 흑막   소서러 역대 레이스 카 목록

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

# %%
count
# Out:
# Counter({'신흥': 19,
#          '재': 69,
#          '출생': 10,
#          '년': 1248,
#          '월': 1330,
#          '경상남도': 1,
#          '김해시': 2,
#          '거주지': 3,
#          '서울특별시': 16,
#          '마포구': 3,
#          '연남동': 1,
#          '국적': 22,
#          '대한민국': 131,
#          '본관': 1,
#          '거창': 1,
#          '신씨': 1,
#          '신체': 30,
#          '형': 54,
#          '데뷔': 23,
#          '웃찾사': 6,
#          '타임머신': 4,
#          '일로': 20,
#          '일': 1138,
#          '주년': 20,
#          '학력': 7,
#          '경운': 1,
#          '초등학교': 16,
#          '졸업': 62,
#          '임호중': 1,
#          '학교': 310,
#          '김해': 4,
#          '고등학교': 66,
#          '세종대': 2,
#          '자정': 4,
#          '보통신': 1,
#          '학부': 12,
#          '휴학': 1,
#          '경력': 17,
#          '공채': 2,
#          '기': 147,
#          '개그맨': 3,
#          '홍보': 29,
#          '대사': 57,
#          '위촉': 2,
#          '상제': 1,
#          '회': 293,
#          '세상': 54,
#          '인': 87,
#          '플루': 6,
#          '어워드': 1,
#          '본상': 1,
#          '소개': 40,
#          '출연': 65,
#          '작품': 79,
#          '방송': 65,
#          '웹': 6,
#          '드라마': 28,
#          '유튜브': 75,
#          '라디오': 31,
#          '유행어': 17,
#          '등': 1012,
#          '미디어': 37,
#          '컨셉': 30,
#          '여담': 131,
#          '저': 73,
#          '신': 56,
#          '흥이': 6,
#          '재미': 17,
#          '코미디언': 1,
#          '정식': 39,
#          '전': 425,
#          '선배': 18,
#          '코너': 4,
#          '극장': 8,
#          '개그': 20,
#          '공연': 13,
#          '후': 515,
#          '폐지': 58,
#          '채널': 102,
#          '를': 548,
#          '김성기': 2,
#          '김재': 1,
#          '운영': 85,
#          '중이': 62,
#          '다년': 112,
#          '개인': 49,
#          '토요일': 9,
#          '시': 573,
#          '영상': 319,
#          '무슨': 33,
#          '이유': 182,
#          '현재': 283,
#          '주제': 14,
#          '먹방': 7,
#          '프로그램': 51,
#          '비고': 20,
#          '카리스마': 3,
#          '유봉': 1,
#          '쌤': 1,
#          '풍문': 1,
#          '문과': 17,
#          '이과': 20,
#          '누가': 24,
#          '진상': 6,
#          '개그투나잇': 1,
#          '뻔데기': 1,
#          '펀': 6,
#          '왜': 59,
#          '갤럭시': 25,
#          '프로젝트': 63,
#          '뉴스': 25,
#          '저녁': 19,
#          '상사': 14,
#          '백만': 6,
#          '유': 32,
#          '튜버': 5,
#          '역': 81,
#          '퇴사': 5,
#          '있긔': 3,
#          '없긔': 3,
#          '진행': 192,
#          '이진행': 1,
#          '노동': 4,
#          '자': 68,
#          '로드': 31,
#          '서울': 150,
#          '미래': 73,
#          '유산': 11,
#          '편': 249,
#          '고정': 32,
#          '디자인': 34,
#          '재단': 62,
#          '트렌드': 5,
#          '피디': 19,
#          '쇼': 31,
#          '크리에이터': 2,
#          '세터': 1,
#          '게스트': 14,
#          '빵': 17,
#          '부바': 1,
#          '거지': 12,
#          '젝': 1,
#          '그': 1007,
#          '각': 71,
#          '몇': 59,
#          '도인': 1,
#          '구': 79,
#          '칼카': 1,
#          '알': 242,
#          '철': 66,
#          '헬리': 1,
#          '베붕': 1,
#          '산수': 1,
#          '금지': 77,
#          '화목': 2,
#          '토': 195,
#          '천해': 1,
#          '분자': 4,
#          '분모': 2,
#          '진분수': 1,
#          '가분수': 1,
#          '일십백천만': 1,
#          '억조경해': 1,
#          '구간': 20,
#          '정재': 6,
#          '여기': 232,
#          '떡볶이': 8,
#          '집': 151,
#          '거리': 99,
#          '너': 79,
#          '초': 424,
#          '치면': 81,
#          '시간': 448,
#          '거기': 76,
#          '튀김': 19,
#          '순대': 11,
#          '계산': 24,
#          '포장': 6,
#          '다시': 242,
#          '무게': 13,
#          '속도': 256,
#          '영향': 91,
#          '때문': 974,
#          '등신': 2,
#          '주인공': 62,
#          '일등': 3,
#          '역할': 63,
#          '수치': 54,
#          '상대': 188,
#          '말': 614,
#          '수학': 15,
#          '과학': 27,
#          '반박': 13,
#          '속': 138,
#          '편이': 181,
#          '정도': 595,
#          '불량': 16,
#          '학생': 142,
#          '때': 1043,
#          '권유': 11,
#          '공부': 22,
#          '관심': 60,
#          '가지': 263,
#          '전국': 53,
#          '제패': 2,
#          '대표': 124,
#          '주자': 18,
#          '기메': 2,
#          '시절': 101,
#          '괴롭힘': 2,
#          '스승': 30,
#          '강경호': 1,
#          '자신': 503,
#          '수': 2055,
#          '격투기': 2,
#          '기술': 87,
#          '도중': 44,
#          '분노': 32,
#          '바람': 63,
#          '만': 424,
#          '순식간': 21,
#          '고로': 17,
#          '전학': 2,
#          '일기장': 4,
#          '배신': 18,
#          '감': 50,
#          '젠': 56,
#          '더': 783,
#          '이상': 450,
#          '예전': 30,
#          '계획': 100,
#          '나신': 1,
#          '분': 231,
#          '안경': 13,
#          '트라우마': 13,
#          '이용': 214,
#          '대결': 14,
#          '잼': 4,
#          '재의': 1,
#          '동생': 30,
#          '잠옷': 5,
#          '항상': 41,
#          '라이언': 23,
#          '것': 2249,
#          '보아': 52,
#          '듯': 162,
#          '사투리': 7,
#          '미신': 6,
#          '뒤': 321,
#          '소개팅': 6,
#          '녀': 5,
#          '꿈': 45,
#          '여친': 1,
#          '행복': 10,
#          '성적': 68,
#          '순이': 15,
#          '기준': 312,
#          '세로': 9,
#          '전교': 5,
#          '꼴등뒤': 1,
#          '엄마': 34,
#          '핑': 5,
#          '캠핑': 5,
#          '물건': 31,
#          '사랑': 58,
#          '출신': 77,
#          '행동': 51,
#          '그것': 63,
#          '앞': 172,
#          '욕': 47,
#          '난리': 10,
#          '부자': 5,
#          '아빠': 23,
#          '처음': 216,
#          '다년생': 1,
#          '자식': 12,
#          '여고': 2,
#          '주현정': 1,
#          '영석': 1,
#          '막내아들': 1,
#          '크기': 39,
#          '평이': 8,
#          '벤츠': 1,
#          '클래스': 46,
#          '건달': 4,
#          '쌤눈': 1,
#          '뿌리': 18,
#          '채': 74,
#          '호두과자': 1,
#          '뿐': 91,
#          '선생님': 35,
#          '야구': 20,
#          '방망이': 3,
#          '지각': 2,
#          '번': 1811,
#          '패거리': 1,
#          '루트': 10,
#          '확률': 256,
#          '높이': 23,
#          '타짜': 4,
#          '싸움': 44,
#          '대가': 38,
#          '감정': 22,
#          '계산기': 2,
#          '약': 128,
#          '가문': 23,
#          '통일': 25,
#          '시대': 31,
#          '예체능': 2,
#          '통합': 42,
#          '초아': 3,
#          '할아버지': 14,
#          '영광': 3,
#          '위해': 295,
#          '끼리': 19,
#          '휘파람': 1,
#          '소리': 99,
#          '쪽': 143,
#          '귀': 8,
#          '포기': 38,
#          '멘트': 3,
#          '두': 193,
#          '동안': 112,
#          '밤': 50,
#          '교복': 2,
#          '방': 265,
#          '가기': 35,
#          '몰카': 7,
#          '진짜': 57,
#          '오해': 24,
#          '초등학생': 3,
#          '부회장': 2,
#          '회장': 16,
#          '선거': 125,
#          '운동': 60,
#          '팻말': 4,
#          '카카오': 6,
#          '프렌즈': 6,
#          '가끔': 102,
#          '제품': 100,
#          '사무실': 2,
#          '액자': 1,
#          '덕후': 4,
#          '또한': 341,
#          '보라색': 17,
#          '찍기': 14,
#          '홍안': 1,
#          '얼굴': 59,
#          '적': 564,
#          '화장품': 2,
#          '직원': 37,
#          '술': 41,
#          '모습': 222,
#          '대학교': 228,
#          '학점': 5,
#          '인스타그램': 7,
#          '학년': 47,
#          '게시': 45,
#          '물의': 39,
#          '해시태그': 1,
#          '구장': 5,
#          '내용': 329,
#          '모든': 232,
#          '과목': 3,
#          '진로': 1,
#          '희망이': 2,
#          '의사': 40,
#          '부모님': 12,
#          '판사': 8,
#          '다실': 3,
#          '제로': 20,
#          '음식': 41,
#          '신길동': 1,
#          '짬뽕': 5,
#          '여러': 139,
#          '짝눈': 1,
#          '양옆': 2,
#          '이미지': 78,
#          '다른': 538,
#          '느낌': 31,
#          '금은': 11,
#          '바이올린': 3,
#          '연주': 11,
#          '본가': 2,
#          '요미': 1,
#          '개': 532,
#          '견종': 2,
#          '코': 190,
#          '어': 12,
#          '글리': 5,
#          '강아지': 4,
#          '다지': 4,
#          '오른손잡이': 1,
#          '과거': 92,
#          '왼손잡이': 3,
#          '페이스북': 6,
#          '위인': 11,
#          '아인슈타인': 1,
#          '버락': 3,
#          '오바마': 20,
#          '중': 770,
#          '방어': 135,
#          '사용': 592,
#          '폰': 40,
#          '기종은': 2,
#          '아이폰': 9,
#          '이': 1402,
#          '당시': 199,
#          '차비': 4,
#          '대학로': 2,
#          '홍대': 1,
#          '원래': 84,
#          '시력': 7,
#          '낮': 9,
#          '주로': 121,
#          '도수': 1,
#          '기념': 53,
#          '라이브': 77,
#          '탕수육': 2,
#          '부': 145,
#          '찍': 6,
#          '상관': 19,
#          '짜장면': 3,
#          '물냉면': 1,
#          '비빔냉면': 2,
#          '된장찌개': 2,
#          '김치찌개': 2,
#          '굽네치킨': 2,
#          '굽': 2,
#          '제일': 61,
#          '치킨': 21,
#          '볼케이노': 1,
#          '너구리': 2,
#          '재희': 2,
#          '라면': 141,
#          '사라': 6,
#          '성기': 11,
#          '목욕탕': 5,
#          '팬': 87,
#          '만난': 26,
#          '실제': 163,
#          '인터뷰': 43,
#          '나': 135,
#          '조금': 108,
#          '기억': 31,
#          '남아': 14,
#          '완전': 16,
#          '면서': 25,
#          '졸졸': 1,
#          '물속': 1,
#          '몸': 102,
#          '목소리': 64,
#          '기분': 19,
#          '롯데': 17,
#          '상위': 81,
#          '문서': 1541,
#          '히메지': 24,
#          '마': 151,
#          '교': 78,
#          '메이': 80,
#          '개요': 46,
#          '행적': 16,
#          '살대': 10,
#          '합': 9,
#          '재판': 33,
#          '무한': 41,
#          '열차': 9,
#          '대장장이': 2,
#          '마을': 48,
#          '합동': 6,
#          '강화': 72,
#          '훈련': 45,
#          '최종': 112,
#          '국면': 1,
#          '상현': 4,
#          '코쿠': 2,
#          '시보': 4,
#          '키부츠': 5,
#          '무잔': 25,
#          '최후': 19,
#          '사후': 13,
#          '에필로그': 1,
#          '멸': 18,
#          '칼날': 3,
#          '등장인물': 36,
#          '스포일러': 31,
#          '포함': 117,
#          '설명': 157,
#          '인물': 198,
#          '대한': 369,
#          '줄거리': 9,
#          '결말': 11,
#          '반전': 12,
#          '요소': 55,
#          '직': 33,
#          '간접': 16,
#          '어머니': 51,
#          '사망': 135,
#          '아버지': 162,
#          '유행병': 1,
#          '열병': 1,
#          '친척': 9,
#          '어린시절': 2,
#          '절': 13,
#          '자라': 5,
#          '성격': 28,
#          '어른': 6,
#          '절의': 2,
#          '승려': 7,
#          '로서': 56,
#          '명의': 57,
#          '아들': 90,
#          '살': 69,
#          '피': 131,
#          '삶': 9,
#          '곳': 215,
#          '도깨비': 44,
#          '전승': 6,
#          '등꽃': 2,
#          '향': 69,
#          '접근': 59,
#          '물리': 22,
#          '날': 147,
#          '고아': 2,
#          '아이': 140,
#          '운': 42,
#          '살기': 8,
#          '비롯': 39,
#          '가족': 81,
#          '목숨': 28,
#          '달라': 54,
#          '곧바로': 12,
#          '필사': 10,
#          '맹인': 3,
#          '그다지': 20,
#          '보이지': 30,
#          '신뢰': 25,
#          '멋대로': 1,
#          '밖': 47,
#          '세': 222,
#          '어둠': 52,
#          '목덜미': 1,
#          '마지막': 173,
#          '요': 32,
#          '사투': 4,
#          '쉬': 33,
#          '맨손': 10,
#          '박살': 29,
#          '생물': 15,
#          '감각': 9,
#          '지옥': 12,
#          '평생': 9,
#          '경험': 53,
#          '혼란': 12,
#          '소란': 5,
#          '사람': 524,
#          '일이': 17,
#          '판단': 37,
#          '동시': 84,
#          '극도': 12,
#          '절망': 9,
#          '살인죄': 1,
#          '투옥': 5,
#          '이후': 644,
#          '누명': 7,
#          '사건': 317,
#          '불신': 5,
#          '카마': 5,
#          '남매': 4,
#          '가차': 2,
#          '준': 64,
#          '모양': 40,
#          '에피소드': 25,
#          '호흡': 15,
#          '정작': 35,
#          '살인자': 2,
#          '매도': 5,
#          '거절': 22,
#          '대략': 35,
#          '흐름': 12,
#          '나즈': 5,
#          '형제': 20,
#          '일과': 7,
#          '시점': 64,
#          '상처': 21,
#          '후회': 4,
#          '겐야': 15,
#          '제자': 26,
#          '삼고': 2,
#          '얼마나': 43,
#          '운명': 15,
#          '부분': 359,
#          '승격': 7,
#          '어르신': 19,
#          '호위': 17,
#          '임무': 14,
#          '주': 128,
#          '죽': 84,
#          '쵸우': 5,
#          '카나': 11,
#          '노부': 26,
#          '자매': 26,
#          '얼마': 49,
#          '생각': 328,
#          '은': 97,
#          '로부터': 41,
#          '이야기': 99,
#          '부탁': 43,
#          '마는': 14,
#          '그대로': 110,
#          '집안일': 2,
#          '도우': 3,
#          '설득': 23,
#          '체격': 8,
#          '거듭': 10,
#          '구실': 3,
#          '뒷마당': 1,
#          '바위': 18,
#          '밀면': 11,
#          '육성': 15,
#          '제안': 40,
#          '마치': 42,
#          '밑': 50,
#          '구멍': 9,
#          '파': 79,
#          '지렛대': 1,
#          '약간': 83,
#          '해도': 110,
#          '이름': 364,
#          '대원': 13,
#          '난': 47,
#          '마님': 1,
#          '반면': 52,
#          '아저씨': 14,
#          '나이': 58,
#          '항의': 7,
#          '마씨': 3,
#          '어찌': 10,
#          '리도': 3,
#          '볼품': 2,
#          '애란': 1,
#          '도': 234,
#          '자체': 210,
#          '다카': 7,
#          '마도': 3,
#          '탄지': 25,
#          '로': 298,
#          '데리': 17,
#          '혐의': 6,
#          '즉결': 1,
#          '처형': 2,
#          '강경': 11,
#          '수주': 4,
#          '로코': 5,
#          '키': 199,
#          '사콘지': 1,
#          '토미': 6,
#          '오카': 13,
#          '기유': 5,
#          '탄원서': 1,
#          '네미': 23,
#          '자기': 99,
#          '피로': 11,
#          '유혹': 8,
#          '습격': 17,
#          '존재': 206,
#          '용인': 10,
#          '염주': 2,
#          '렌고쿠': 1,
#          '쿄쥬로': 1,
#          '삼': 5,
#          '카': 279,
#          '교전': 7,
#          '전사': 23,
#          '소식': 23,
#          '눈물': 25,
#          '옆': 67,
#          '츠구코': 1,
#          '떡밥': 12,
#          '회의': 60,
#          '악화': 12,
#          '못': 196,
#          '좀': 149,
#          '기원': 19,
#          '부인': 9,
#          '아마': 31,
#          '마음': 64,
#          '하라': 40,
#          '격려': 4,
#          '반점': 13,
#          '관': 136,
#          '달리': 156,
#          '고향': 18,
#          '대해': 186,
#          '무': 182,
#          '이치로': 14,
#          '발현': 11,
#          '조건': 65,
#          '의논': 3,
#          '관계': 86,
#          '도발': 8,
#          '시비': 9,
#          '걸': 206,
#          '제지': 5,
#          '하나': 351,
#          '다공': 1,
#          '소설': 31,
#          '판': 1315,
#          '모두': 230,
#          '와중': 29,
#          '참가': 42,
#          '전하': 6,
#          '독': 37,
#          '보고': 202,
#          '무언가': 15,
#          '예감': 1,
#          '라며': 38,
#          '간만': 5,
#          '누': 19,
#          '이의': 8,
#          '원수': 14,
#          '일념': 7,
#          '아무': 49,
#          '생전': 12,
#          '똑': 2,
#          '미소': 9,
#          '작별인사': 1,
#          '형용': 1,
#          '텐구': 1,
#          '태양': 10,
#          '극복': 10,
#          '역시': 197,
#          '전력': 57,
#          '지역': 224,
#          '전부': 131,
#          '후퇴': 17,
#          '잠시': 39,
#          '통한': 32,
#          '언급': 123,
#          '근신': 2,
#          '근육': 7,
#          '수행': 29,
#          '첫': 145,
#          '개울물': 1,
#          '폭포': 2,
#          '두번째': 26,
#          '통나무': 5,
#          '짊': 2,
#          '지기': 9,
#          '세번': 12,
#          '촌': 7,
#          '하드코어': 34,
#          '난이도': 200,
#          '기도': 136,
#          '터프': 1,
#          '이노': 17,
#          '스케': 21,
#          '실신': 3,
#          '놈': 65,
#          '미리': 42,
#          '낙오': 2,
#          '자도': 9,
#          '꽤': 112,
#          '한편': 57,
#          '경고': 28,
#          '무시': 60,
#          '사고': 77,
#          '뻔': 10,
#          '덕분': 70,
#          '미수': 7,
#          '젠이츠': 7,
#          '불': 129,
#          '보': 63,
#          '긴장': 11,
#          '물': 154,
#          '명령': 36,
#          '친구': 176,
#          '끝내': 12,
#          '속임수': 3,
#          '현실': 49,
#          '하자': 98,
#          '밀고': 14,
#          '멘붕': 3,
#          '현': 45,
#          '최강': 26,
#          '평가': 90,
#          '혼자': 45,
#          '냄새': 3,
#          '동의': 18,
#          '위': 605,
#          '반복': 30,
#          '동작': 17,
#          '나무': 74,
#          '몰래': 13,
#          '밀': 15,
#          '양반': 12,
#          '식': 70,
#          '뒷담화': 1,
#          '나름': 40,
#          '충격': 36,
#          '표정': 21,
#          '자극': 17,
#          '탈수증': 1,
#          '끝': 107,
#          '달성': 49,
#          '칭찬': 10,
#          '결단': 2,
#          '리지': 19,
#          '결정': 114,
#          '며': 26,
#          '부정': 24,
#          '오히려': 87,
#          '순진무구': 1,
#          '더욱': 61,
#          '짓': 27,
#          '덩어리': 5,
#          '의심': 21,
#          '풀': 62,
#          '하든': 5,
#          '인정': 43,
#          '건': 195,
#          '누구': 28,
#          '마찬가지': 96,
#          '길': 76,
#          '잘못': 41,
#          '사': 73,
#          '머리': 76,
#          '본부': 26,
#          '저택': 17,
#          '자폭': 11,
#          '휘': 15,
#          '타마요': 2,
#          '움직임': 29,
#          '봉쇄': 11,
#          '인간': 72,
#          '박아': 13,
#          '본인': 214,
#          '시종': 1,
#          '시로': 28,
#          '혈': 11,
#          '숨기': 8,
#          '기회': 38,
#          '오자': 6,
#          '목': 47,
#          '회상': 14,
#          '가야로': 1,
#          '뜻': 52,
#          '차마': 2,
#          '거스': 3,
#          '재생': 24,
#          '예측': 14,
#          '게': 261,
#          '해': 91,
#          '아침': 12,
#          '각오': 9,
#          '마침': 12,
#          '도달': 13,
#          '한번': 73,
#          '키메': 2,
#          '간다': 38,
#          '잡': 34,
#          '죽음': 25,
#          '절대로': 19,
#          '곱': 3,
#          '화': 162,
#          '거처': 4,
#          '방향': 46,
#          '백세': 1,
#          '모조리': 10,
#          '등장': 622,
#          '코쿠시보': 42,
#          '본격': 30,
#          '이귀': 1,
#          '정면': 8,
#          '격돌': 2,
#          '표현': 37,
#          '온몸': 2,
#          '최고': 108,
#          '수준': 154,
#          '철퇴': 4,
#          '도끼': 25,
#          '붙이': 13,
#          '검': 97,
#          '파괴': 117,
#          '무지막지': 6,
#          '강하': 9,
#          '무기': 94,
#          '둘': 92,
#          '사슬': 6,
#          '품질': 17,
#          '쇠': 10,
#          '태양광': 2,
#          '세포': 21,
#          '벨': 5,
#          '수가': 89,
#          '유문암': 1,
#          '속정': 1,
#          '응수': 1,
#          '달': 104,
#          '주화': 1,
#          '농월': 1,
#          '찰나': 3,
#          '순간': 41,
#          '베이': 18,
#          '패': 156,
#          '도로아미타불': 2,
#          '막상막하': 1,
#          '이전': 1340,
#          '오늘밤': 1,
#          '한탄': 7,
#          '잡념': 1,
#          '강요': 11,
#          '이내': 30,
#          '방금': 2,
#          '막': 65,
#          '눈치': 21,
#          '예외': 12,
#          '거짓말': 14,
#          '지적': 28,
#          '거짓': 9,
#          '단': 166,
#          '의아': 8,
#          '살이': 6,
#          '화가': 9,
#          '시작': 399,
#          '꿰메': 1,
#          '보조': 44,
#          '통해': 130,
#          '기모노': 1,
#          '베': 17,
#          '난도질': 1,
#          '공격': 539,
#          '얼추': 2,
#          '궤도': 4,
#          '손가락': 10,
#          '절단': 5,
#          '선': 159,
#          '보호': 30,
#          '이윽고': 4,
#          '연달': 4,
#          '통': 54,
#          '집중': 64,
#          '피하': 27,
#          '비치': 20,
#          '세계': 155,
#          '터득': 1,
#          '돌진': 11,
#          '의도': 31,
#          '치기': 30,
#          '직전': 33,
#          '온': 83,
#          '칼': 65,
#          '여파': 9,
#          '이치': 28,
#          '상반신': 1,
#          '하반신': 4,
#          '분리': 66,
#          '사실': 349,
#          '치명상': 4,
#          '자질': 3,
#          '틈': 17,
#          '매개': 4,
#          '꼼짝': 3,
#          '협동': 3,
#          '당황': 29,
#          '토키': 4,
#          '토의': 11,
#          '희생': 15,
#          '헛되이': 1,
#          '안': 400,
#          '마침내': 14,
#          '소멸': 2,
#          '데': 137,
#          '의식': 26,
#          '상태': 264,
#          '계속': 161,
#          '진정': 6,
#          '부축': 2,
#          '시신': 13,
#          '수습': 16,
#          '존경': 11,
#          '감사': 12,
#          '표': 170,
#          '오리': 27,
#          '눈': 134,
#          '주입': 6,
#          '탓': 40,
#          '붕괴': 17,
#          '칸': 73,
#          '로지': 23,
#          '미츠리': 3,
#          '사주': 5,
#          '이구': 2,
#          '바나': 4,
#          '위기': 28,
#          '처': 27,
#          '가슴': 14,
#          '촉수': 3,
#          '관통': 7,
#          '구로': 22,
#          ...})

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'역사': 1568, '문서': 1541, '문단': 1476, '이전': 1340, '때문': 974, '경우': 964, '헌혈': 758, '배율': 736, '접종': 685, '스테이지': 680, '이후': 644, '백신': 623, '등장': 622, '정도': 595, '사용': 592, '공격': 539, '다른': 538, '사람': 524, '자신': 503, '체력': 485, '마리': 458, '캐릭터': 456, '이상': 450, '시간': 448, '게임': 447, '좀비': 434, '아이템': 400, '시작': 399, '블록': 384, '대한': 369, '사항': 365, '이름': 364, '부분': 359, '하나': 351, '사실': 349, '또한': 341, '내용': 329, '생각': 328, '영상': 319, '가장': 319, '토론': 318, '사건': 317, '문제': 315, '기준': 312, '학교': 310, '보스': 309, '합의': 309, '한국': 308, '공화당': 304, '다만': 299, '위해': 295, '주의': 294, '미국': 294, '관련': 290, '현재': 283, '난도': 282, '드랍': 270, '블랙': 267, '상태': 264, '가지': 263, '스코틀랜드': 261, '속성': 258, '속도': 256, '확률': 256, '영국': 254, '참고': 251, '조선': 251, '상황': 249, '고양이': 249, '해당': 246, '추가': 245, '티켓': 244, '다시': 242, '유닛': 241, '매우': 237, '최대': 236, '여기': 232, '모든': 232, '모두': 230, '정부': 229, '대학교': 228, '능력': 228, '메탈': 228, '카드': 227, '지역': 224, '모습': 222, '성능': 221, '갤러리': 218, '처음': 216, '이용': 214, '본인': 214, '자체': 210, '독립': 208, '일부': 207, '혈액': 207, '존재': 206, '보고': 202, '난이도': 200, '천사': 200, '당시': 199, '데미지': 199, '인물': 198, '교육': 198, '역시': 197, '진행': 192, '시리즈': 192, '효과': 191, '대부분': 190, '베컴': 190, '후보': 190, '상대': 188, '대해': 186, '이유': 182, '방법': 182, '편이': 181, '시즌': 180, '일반': 178, '레벨': 177, '친구': 176, '전체': 175, '관리': 175, '지원': 174, '일본': 174, '마지막': 173, '다음': 173, '거의': 172, '대신': 172, '코로나': 171, '요구': 170, '여성': 170, '기본': 170, '선택': 169, '버전': 169, '구매': 167, '소환': 167, '제외': 166, '통솔력': 165, '민주당': 164, '하마': 164, '실제': 163, '아버지': 162, '스킬': 162, '계속': 161, '레이': 161, '가능': 161, '마플': 161, '바로': 159, '확인': 159, '수도': 158, '도입': 158, '직접': 158, '설명': 157, '그냥': 157, '달리': 156, '격리': 156, '세계': 155, '수준': 154, '치사': 154, '클리어': 153, '논란': 152, '주요': 151, '서울': 150, '지금': 150, '기록': 148, '대학': 147, '폭발': 147, '사이': 146, '대통령': 146, '스타': 145, '트럼프': 144, '투표': 144, '라인': 143, '학생': 142, '라면': 141, '초반': 141, '아이': 140, '결과': 140, '실종자': 140, '여러': 139, '승리': 139, '영화': 139, '감소': 138, '피해': 138, '국가': 138, '미션': 137, '럭키': 137, '기도': 136, '방어': 135, '사망': 135, '마이너': 135, '특성': 134, '검사': 132, '대한민국': 131, '여담': 131, '전부': 131, '업데이트': 131, '통해': 130, '플레이어': 130, '위치': 129, '기타': 128, '발생': 128, '접기': 127, '멍뭉이': 127, '에릭': 126, '선거': 125, '대표': 124, '가능성': 124, '언급': 123, '주장': 123, '경험치': 123, '화이자': 123, '주로': 121, '경기': 121, '거나': 120, '계약': 120, '개다래': 120, '파워': 119, '이기': 119, '유지': 118, '보통': 118, '가격': 118, '포함': 117, '파괴': 117, '업그레이드': 117, '비교': 116, '히어로': 116, '개발': 116, '국내': 116, '보상': 116, '유저': 116, '플레이': 115, '아스': 115, '결정': 114, '기사': 114, '처리': 113, '자리': 113, '사기': 113, '웨이브': 113, '다년': 112, '동안': 112, '최종': 112, '선수': 111, '지지': 111, '컨텐츠': 111, '그대로': 110, '해도': 110, '병원': 110, '입장': 109, '추천': 109, '종류': 109, '마인크래프트': 109, '조금': 108, '최고': 108, '국민': 108, '세대': 108, '크게': 107, '명분': 107, '레드': 107, '계급': 106, '세력': 106, '인원': 106, '의료': 106, '혈장': 106, '냥코': 106, '쿨러': 105, '먼저': 104, '반대': 104, '사거리': 104, '이벤트': 104, '청원': 104, '합성': 104, '차이': 103, '스펠': 103, '채널': 102, '가끔': 102, '스토리': 102, '필요': 102, '증가': 102, '히트': 102, '물량': 102, '딜러': 102, '딜런': 102, '루하시': 102, '시절': 101, '사진': 101, '저항': 101, '예정': 101, '아키': 101, '커트': 101, '낙선': 101, '계획': 100, '제품': 100, '정보': 100, '모드': 100, '아래': 100, '거리': 99, '소리': 99, '이야기': 99, '자기': 99, '구성': 99, '감독': 99, '공급': 99, '반란': 99, '하자': 98, '인구': 98, '직업': 98, '아예': 97, '참여': 97, '마찬가지': 96, '설치': 96, '내부': 96, '밴드': 96, '반응': 96, '삭제': 96, '시라': 96, '선풍기': 96, '도구': 95, '중앙': 95, '데이비드': 95, '질병': 95, '병력': 95, '징병제': 95, '무기': 94, '남성': 94, '잉글랜드': 94, '스코어': 94, '혈소판': 94, '나라': 93, '스탠드': 93, '과거': 92, '리그': 92, '음료': 92, '의원': 92, '종로구': 92, '영향': 91, '대상': 91, '제작': 91, '획득': 91, '갈이': 91, '우선': 91, '아들': 90, '평가': 90, '활동': 90, '교수': 90, '케이스': 90, '하루': 90, '기존': 90, '메인보드': 90, '수가': 89, '확보': 89, '컴퓨터': 89, '드레스': 89, '대항': 89, '그래픽': 89, '만원': 88, '탄약': 88, '기술': 87, '오히려': 87, '주민': 87, '이동': 87, '전쟁': 87, '용량': 87,  ...

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
#!pip install pytagcloud pygame simplejson
# Out:
# Collecting pytagcloud
#   Downloading pytagcloud-0.3.5.tar.gz (754 kB)
# Collecting pygame
#   Downloading pygame-2.0.1-cp37-cp37m-win_amd64.whl (5.2 MB)
# Collecting simplejson
#   Downloading simplejson-3.17.2-cp37-cp37m-win_amd64.whl (73 kB)
# Building wheels for collected packages: pytagcloud
#   Building wheel for pytagcloud (setup.py): started
#   Building wheel for pytagcloud (setup.py): finished with status 'done'
#   Created wheel for pytagcloud: filename=pytagcloud-0.3.5-py3-none-any.whl size=759878 sha256=1b93f45633c865fbb6e5920fa5a75f62cd8d50ee6c93b1bf40233a673993773b
#   Stored in directory: c:\users\tjoeun709\appdata\local\pip\cache\wheels\fc\fd\aa\86956a295a7c9205bafd518ef4b6d489e51d2d476990c18238
# Successfully built pytagcloud
# Installing collected packages: simplejson, pytagcloud, pygame
# Successfully installed pygame-2.0.1 pytagcloud-0.3.5 simplejson-3.17.2

# %%
import random
import pytagcloud
import webbrowser
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %%
count
# Out:
# Counter({'신흥': 1,
#          '재': 1,
#          '히메지': 1,
#          '마': 1,
#          '교': 1,
#          '메이': 1,
#          '중': 1,
#          '행적': 1,
#          '소의문': 1,
#          '펀': 1,
#          '등장인물': 2,
#          '한국': 1,
#          '교원대': 1,
#          '학교': 1,
#          '랜덤': 1,
#          '로얄': 1,
#          '문제점': 1,
#          '데이비드': 1,
#          '베컴': 1,
#          '파일': 3,
#          '좀비': 1,
#          '코로나바이러스': 1,
#          '감염증': 1,
#          '대한민국': 2,
#          '소설': 1,
#          '여단': 1,
#          '에이지': 1,
#          '오브': 1,
#          '엠파이어': 1,
#          '결정': 1,
#          '판': 1,
#          '캠페인': 1,
#          '공략': 1,
#          '트': 1,
#          '마리아': 1,
#          '루스': 1,
#          '호': 1,
#          '사건': 3,
#          '마인크래프트': 3,
#          '아이템': 3,
#          '더미': 1,
#          '데이터': 1,
#          '및': 1,
#          '삭제': 1,
#          '요리': 1,
#          '샨': 1,
#          '민주주의': 1,
#          '민족': 1,
#          '동맹': 1,
#          '틀': 1,
#          '영화': 2,
#          '배급사': 1,
#          '한강': 1,
#          '의대': 1,
#          '생': 1,
#          '실종': 1,
#          '경과': 1,
#          '건축': 1,
#          '블록': 1,
#          '여성': 1,
#          '징병제': 1,
#          '청원': 1,
#          '후': 2,
#          '폰테': 1,
#          '정규수': 1,
#          '동방환상향': 1,
#          '커트': 1,
#          '코베': 1,
#          '종로구': 1,
#          '선거구': 1,
#          '사업': 1,
#          '본부': 1,
#          '냥코': 2,
#          '전쟁': 2,
#          '발굴': 1,
#          '스테이지': 2,
#          '카미': 1,
#          '하야토': 1,
#          '헌혈': 1,
#          '시라': 1,
#          '사기': 1,
#          '치사': 1,
#          '토': 1,
#          '클리블랜드': 1,
#          '인디언스': 1,
#          '년월': 1,
#          '선풍기': 1,
#          '사망설': 1,
#          '야인시대': 1,
#          '합성': 1,
#          '물': 1,
#          '조립': 1,
#          '컴퓨터': 1,
#          '견적': 1,
#          '테': 1,
#          '루하시': 1,
#          '코': 1,
#          '코미': 1,
#          '동방': 1,
#          '로스트': 1,
#          '워드': 1,
#          '코튼': 1,
#          '스타벅스': 1,
#          '메뉴': 1,
#          '철구': 1,
#          '사랑': 1,
#          '콜럼': 1,
#          '바인': 1,
#          '고교': 1,
#          '총기': 1,
#          '난사': 1,
#          '고종': 1,
#          '군밤': 1,
#          '왕': 1,
#          '림': 1,
#          '월드': 1,
#          '짤방': 1,
#          '목록': 2,
#          '세스': 1,
#          '후랭코프': 1,
#          '풍운': 1,
#          '타케시': 1,
#          '경기': 1,
#          '모바일': 1,
#          '과학': 1,
#          '고등학교': 1,
#          '서버': 1,
#          '강제': 1,
#          '퇴장': 1,
#          '메시지': 1,
#          '마이애미': 1,
#          '히트': 1,
#          '마이너': 1,
#          '갤러리': 1,
#          '마인': 1,
#          '애플': 1,
#          '두부': 1,
#          '인터넷': 1,
#          '방송인': 1,
#          '플레이': 1,
#          '게임': 1,
#          '리스트': 1,
#          '공화당': 1,
#          '미국': 1,
#          '스코틀랜드': 1,
#          '독립운동': 1,
#          '유용': 1,
#          '민': 1,
#          '스타': 1,
#          '플래티나': 1,
#          '스페셜': 1,
#          '흑막': 1,
#          '소': 1,
#          '역대': 1,
#          '레이스': 1,
#          '카': 1})

# %%
dic_count = dict(count)
dic_count['사건']
# Out:
# 3

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')

# %%
from konlpy.tag import Okt

# %%
t = Okt()

# %%
tokens_ko = t.nouns("나는 가방에 들어갈거야..가방..가방...진짜야..진짜..진짜..진짜..진짜..오늘은 수요일이야..오늘")
tokens_ko
# Out:
# ['나', '가방', '가방', '가방', '진짜', '진짜', '진짜', '진짜', '진짜', '오늘', '수요일', '오늘']

# %%
import nltk

# %%
ko = nltk.Text(tokens_ko, name='test')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도
 
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.font_manager as fm
fontpath = 'C:/ProgramData/Anaconda3/Lib/site-packages/pytagcloud/fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=fontpath, size=9).get_name()
plt.rc('font', family=font_name)

# %%
fm._rebuild() #폰트 설정 반영

# %%
plt.figure(figsize=(14,6))
ko.plot(50)
plt.show()

# %%
coun
